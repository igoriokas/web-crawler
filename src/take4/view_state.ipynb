# %%
import pandas as pd
import sqlite3
import os

if not os.getcwd().endswith('/run'):
    os.chdir('run')

DBNAME = "state.db"

# %%
with sqlite3.connect(DBNAME) as conn:
    df = pd.read_sql("SELECT * FROM pages", conn)
df
# Out:
#      sid                                                url  depth   status  \
# 0      1              https://books.toscrape.com/index.html      0  visited
# 1      2  https://books.toscrape.com/catalogue/category/...      1  visited
# 2      3  https://books.toscrape.com/catalogue/category/...      1  visited
# 3      4  https://books.toscrape.com/catalogue/category/...      1  visited
# 4      5  https://books.toscrape.com/catalogue/category/...      1  visited
# ..   ...                                                ...    ...      ...
# 291  292  https://books.toscrape.com/catalogue/maude-188...      2   queued
# 292  293  https://books.toscrape.com/catalogue/behind-cl...      2   queued
# 293  294  https://books.toscrape.com/catalogue/you-cant-...      2   queued
# 294  295   https://books.toscrape.com/catalogue/page-1.html      2   queued
# 295  296   https://books.toscrape.com/catalogue/page-3.html      2   queued
#
#      attempts          inserted_at         last_attempt error
# 0           1  2025-07-08 00:34:58  2025-07-08 00:34:58  None
# 1           1  2025-07-08 00:34:59  2025-07-08 00:34:59  None
# 2           1  2025-07-08 00:34:59  2025-07-08 00:35:01  None
# 3           1  2025-07-08 00:34:59  2025-07-08 00:35:02  None
# 4           1  2025-07-08 00:34:59  2025-07-08 00:35:03  None
# ..        ...                  ...                  ...   ...
# 291         0  2025-07-08 00:37:46                 None  None
# 292         0  2025-07-08 00:37:46                 None  None
# 293         0  2025-07-08 00:37:46                 None  None
# 294         0  2025-07-08 00:37:46                 None  None
# 295         0  2025-07-08 00:37:46                 None  None
#
# [296 rows x 8 columns]

# %%
with sqlite3.connect(DBNAME) as conn:
    df = pd.read_sql("SELECT * FROM pages WHERE status = 'failed'", conn)
df
# Out:
#     sid                                                url  depth  status  \
# 0    13  https://books.toscrape.com/catalogue/category/...      1  failed
# 1    14  https://books.toscrape.com/catalogue/category/...      1  failed
# 2    15  https://books.toscrape.com/catalogue/category/...      1  failed
# 3    16  https://books.toscrape.com/catalogue/category/...      1  failed
# 4    19  https://books.toscrape.com/catalogue/category/...      1  failed
# ..  ...                                                ...    ...     ...
# 69   76  https://books.toscrape.com/catalogue/see-ameri...      2  failed
# 70   78  https://books.toscrape.com/catalogue/under-the...      2  failed
# 71   80  https://books.toscrape.com/catalogue/the-great...      2  failed
# 72   81  https://books.toscrape.com/catalogue/a-year-in...      2  failed
# 73   97  https://books.toscrape.com/catalogue/hide-away...      2  failed
#
#     attempts          inserted_at         last_attempt  \
# 0          1  2025-07-08 00:34:59  2025-07-08 00:35:23
# 1          1  2025-07-08 00:34:59  2025-07-08 00:35:24
# 2          1  2025-07-08 00:34:59  2025-07-08 00:35:25
# 3          1  2025-07-08 00:34:59  2025-07-08 00:35:27
# 4          1  2025-07-08 00:34:59  2025-07-08 00:35:35
# ..       ...                  ...                  ...
# 69         2  2025-07-08 00:35:01  2025-07-08 00:37:52
# 70         2  2025-07-08 00:35:01  2025-07-08 00:37:58
# 71         2  2025-07-08 00:35:01  2025-07-08 00:38:02
# 72         2  2025-07-08 00:35:01  2025-07-08 00:38:06
# 73         2  2025-07-08 00:35:02  2025-07-08 00:38:26
#
#                                                 error
# 0   405 Client Error: OK for url: https://books.to...
# 1   400 Client Error: OK for url: https://books.to...
# 2   422 Client Error: OK for url: https://books.to...
# 3   405 Client Error: OK for url: https://books.to...
# 4   405 Client Error: OK for url: https://books.to...
# ..                                                ...
# 69  502 Server Error: OK for url: https://books.to...
# 70  500 Server Error: OK for url: https://books.to...
# 71  502 Server Error: OK for url: https://books.to...
# 72  502 Server Error: OK for url: https://books.to...
# 73  410 Client Error: OK for url: https://books.to...
#
# [74 rows x 8 columns]
