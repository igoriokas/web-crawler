# %%
import pandas as pd
import sqlite3
import os

if not os.getcwd().endswith('/run'):
    os.chdir('run')

DBNAME = "state.db"

# %%
with sqlite3.connect(DBNAME) as conn:
    df = pd.read_sql("SELECT * FROM pages", conn)
df
# Out:
#      sid                                                url  depth   status  \
# 0      1              https://books.toscrape.com/index.html      0  visited
# 1      2  https://books.toscrape.com/catalogue/category/...      1  visited
# 2      3  https://books.toscrape.com/catalogue/category/...      1  visited
# 3      4  https://books.toscrape.com/catalogue/category/...      1  visited
# 4      5  https://books.toscrape.com/catalogue/category/...      1  visited
# ..   ...                                                ...    ...      ...
# 269  270  https://books.toscrape.com/catalogue/chasing-h...      2   queued
# 270  271  https://books.toscrape.com/catalogue/if-i-gave...      2   queued
# 271  272  https://books.toscrape.com/catalogue/unreasona...      2   queued
# 272  273  https://books.toscrape.com/catalogue/a-new-ear...      2   queued
# 273  274  https://books.toscrape.com/catalogue/amid-the-...      2   queued
#
#      attempts          inserted_at         last_attempt error
# 0           1  2025-07-08 11:09:51  2025-07-08 11:09:51  None
# 1           1  2025-07-08 11:09:51  2025-07-08 11:09:52  None
# 2           1  2025-07-08 11:09:51  2025-07-08 11:09:53  None
# 3           1  2025-07-08 11:09:51  2025-07-08 11:09:54  None
# 4           1  2025-07-08 11:09:51  2025-07-08 11:09:55  None
# ..        ...                  ...                  ...   ...
# 269         0  2025-07-08 11:20:08                 None  None
# 270         0  2025-07-08 11:20:08                 None  None
# 271         0  2025-07-08 11:20:08                 None  None
# 272         0  2025-07-08 11:20:08                 None  None
# 273         0  2025-07-08 11:20:46                 None  None
#
# [274 rows x 8 columns]

# %%
with sqlite3.connect(DBNAME) as conn:
    df = pd.read_sql("SELECT * FROM pages WHERE status = 'failed'", conn)
df
# Out:
#     sid                                                url  depth  status  \
# 0    52  https://books.toscrape.com/catalogue/category/...      1  failed
# 1    53  https://books.toscrape.com/catalogue/a-light-i...      1  failed
# 2    54  https://books.toscrape.com/catalogue/tipping-t...      1  failed
# 3    58  https://books.toscrape.com/catalogue/the-requi...      1  failed
# 4    59  https://books.toscrape.com/catalogue/the-dirty...      1  failed
# 5    60  https://books.toscrape.com/catalogue/the-comin...      1  failed
# 6    62  https://books.toscrape.com/catalogue/the-black...      1  failed
# 7    64  https://books.toscrape.com/catalogue/shakespea...      1  failed
# 8    69  https://books.toscrape.com/catalogue/olio_984/...      1  failed
# 9    70  https://books.toscrape.com/catalogue/mesaerion...      1  failed
# 10   71  https://books.toscrape.com/catalogue/libertari...      1  failed
# 11   73   https://books.toscrape.com/catalogue/page-2.html      1  failed
# 12   74  https://books.toscrape.com/catalogue/category/...      2  failed
# 13   75  https://books.toscrape.com/catalogue/full-moon...      2  failed
# 14   77  https://books.toscrape.com/catalogue/vagabondi...      2  failed
# 15   78  https://books.toscrape.com/catalogue/under-the...      2  failed
# 16   84  https://books.toscrape.com/catalogue/1000-plac...      2  failed
# 17   85  https://books.toscrape.com/catalogue/in-a-dark...      2  failed
# 53         2  2025-07-08 11:09:51  2025-07-08 11:20:31
# 54         2  2025-07-08 11:09:51  2025-07-08 11:20:35
# 55         2  2025-07-08 11:09:51  2025-07-08 11:20:38
# 56         2  2025-07-08 11:09:51  2025-07-08 11:20:42
# 57         2  2025-07-08 11:09:51  2025-07-08 11:24:52
# 58         2  2025-07-08 11:09:54  2025-07-08 11:28:10
# 59         2  2025-07-08 11:09:55  2025-07-08 11:28:24
#
#                                      error
# 0           Non-Retryable HTTP error [501]
# 1           Non-Retryable HTTP error [401]
# 2           Non-Retryable HTTP error [400]
# 3           Non-Retryable HTTP error [405]
# 4           Non-Retryable HTTP error [400]
# 5           Non-Retryable HTTP error [200]
# 6           Non-Retryable HTTP error [400]
# 7           Non-Retryable HTTP error [404]
# 8           Non-Retryable HTTP error [422]
# 9           Non-Retryable HTTP error [200]
# 10          Non-Retryable HTTP error [422]
# 11          Non-Retryable HTTP error [200]
# 12          Non-Retryable HTTP error [403]
# 13          Non-Retryable HTTP error [403]
# 14          Non-Retryable HTTP error [405]
# 15          Non-Retryable HTTP error [501]
# 16          Non-Retryable HTTP error [410]
# 17          Non-Retryable HTTP error [405]
# 18          Non-Retryable HTTP error [501]
# 19          Non-Retryable HTTP error [403]
# 20          Non-Retryable HTTP error [410]
# 21          Non-Retryable HTTP error [405]
# 22          Non-Retryable HTTP error [405]
# 23                     Retryable error 502
# 24                     Retryable error 429
# 25                     Retryable error 429
# 26          Non-Retryable HTTP error [200]
# 27              Retryable HTTP error [502]
# 28              Retryable HTTP error [504]
# 29              Retryable HTTP error [503]
# 30              Retryable HTTP error [504]
# 31              Retryable HTTP error [502]
# 32              Retryable HTTP error [503]
# 33              Retryable HTTP error [503]
# 34              Retryable HTTP error [500]
# 35              Retryable HTTP error [429]
# 36              Retryable HTTP error [504]
# 37              Retryable HTTP error [502]
# 38              Retryable HTTP error [429]
# 39              Retryable HTTP error [500]
# 40              Retryable HTTP error [503]
# 41              Retryable HTTP error [500]
# 42              Retryable HTTP error [502]
# 43              Retryable HTTP error [502]
# 44              Retryable HTTP error [502]
# 45              Retryable HTTP error [504]
# 46              Retryable HTTP error [504]
# 47              Retryable HTTP error [502]
# 48              Retryable HTTP error [503]
# 49              Retryable HTTP error [503]
# 50              Retryable HTTP error [502]
# 51              Retryable HTTP error [500]
# 52              Retryable HTTP error [429]
# 53              Retryable HTTP error [429]
# 54              Retryable HTTP error [500]
# 55              Retryable HTTP error [502]
# 56              Retryable HTTP error [504]
# 57  write() argument must be str, not None
# 58              Retryable HTTP error [500]
# 59          Non-Retryable HTTP error [422]

# %%
with sqlite3.connect(DBNAME) as conn:
    df = pd.read_sql("SELECT * FROM pages WHERE status = 'failed' AND error LIKE 'write%'", conn)
df
# Out:
#    sid                                                url  depth  status  \
# 0   51  https://books.toscrape.com/catalogue/category/...      1  failed
#
#    attempts          inserted_at         last_attempt  \
# 0         2  2025-07-08 11:09:51  2025-07-08 11:24:52
#
#                                     error
# 0  write() argument must be str, not None
